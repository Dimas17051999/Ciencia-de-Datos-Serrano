# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
births = pd.read_csv("/content/gdrive/MyDrive/Ciencia de datos :)/birthYearly.csv")
data = pd.read_csv("/content/gdrive/MyDrive/Ciencia de datos :)/data.csv")
df= pd.read_csv("/content/gdrive/MyDrive/Ciencia de datos :)/rain.csv")
temperature = pd.read_csv("/content/gdrive/MyDrive/Ciencia de datos :)/tempYearly.csv")

# %% [markdown]
# # Task 1
# ---

# %%
print(df)
# Out:
#         Month  Rainfall  Temperature
# 0     January     1.650          3.0
# 1    February     1.250         10.0
# 2       March     1.940         15.0
# 3       April     2.750         20.0
# 4         May     3.140         25.0
# 5        June     3.645         24.0
# 6        July     5.500         30.0
# 7      August     1.000          1.0
# 8   September     1.300         33.0
# 9     October       NaN          NaN
# 10   November     0.500         32.0
# 11   December     2.300          2.3

# %%
print("df statistics: ", df.describe())
# Out:
# df statistics:          Rainfall  Temperature
# count  11.000000    11.000000
# mean    2.270455    17.754545
# std     1.432903    12.193553
# min     0.500000     1.000000
# 25%     1.275000     6.500000
# 50%     1.940000    20.000000
# 75%     2.945000    27.500000
# max     5.500000    33.000000

# %%
df.plot(x='Month', y='Temperature')

# %%
df.plot(x='Month', y='Rainfall')

# %%
plt.figure(figsize=(15,5)) #para hacer mas ancha la grafica 
plt.plot(df['Month'], df['Temperature'], label='Temperature')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5)) #para hacer mas ancha la grafica 
plt.plot(df['Month'], df['Rainfall'], label='Rainfall')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5)) #para hacer mas ancha la grafica 
plt.plot(df['Month'], df['Temperature'], label='Temperature')
plt.plot(df['Month'], df['Rainfall'], label='Rainfall')
plt.legend()
plt.show()

# %% [markdown]
# #Task 3
# ---

# %%
#Visualize and analyze the data 

sns.set(rc={'figure.figsize':(12,6)})
sns.regplot(x="Year", y="Temperature",  data= temperature )
plt.show()

# %% [markdown]
# # Task 4
# ---

# %%
#Heat map 
print(births)
# Out:
#         month  year  births
# 0     January  2000     101
# 1    February  2000     168
# 2       March  2000     271
# 3       April  2000     229
# 4         May  2000     287
# ..        ...   ...     ...
# 79     August  2006     243
# 80  September  2006     174
# 81    October  2006      62
# 82   November  2006     175
# 83   December  2006     134
#
# [84 rows x 3 columns]

# %%
dataP = births.pivot("month", "year", "births")
print(dataP)
# Out:
# year       2000  2001  2002  2003  2004  2005  2006
# month
# April       229    75   289   214   261   115   299
# August      238   162    86    97   202   158   243
# December    152   286   175   142    58   269   134
# February    168    64   152    71   285   242   201
# January     101   291   274    70    84   279   299
# July        142   285   125   194    77   235   193
# June        183   112   257   103   199   204   136
# March       271   289   248    54    70   258   196
# May         287   141   112   258   175   125    70
# November    108    69   131   152    99   230   175
# October     263   148   274   235   157   224    62
# September   264    96   123   104    53   225   174

# %%
sns.heatmap(dataP, annot= True, fmt="d")
plt.show()

# %% [markdown]
# #Task 5
# ---

# %%
#Join Plot = scatterplot + histograms
print(temperature)
# Out:
#     Temperature  Year  Rainfall
# 0         16.99  1956      1.01
# 1         10.34  1957      1.66
# 2         21.01  1958      3.50
# 3         23.68  1959      3.31
# 4         24.59  1960      3.61
# ..          ...   ...       ...
# 57        26.41  2013      1.50
# 58        11.24  2014      1.76
# 59        48.27  2015      6.73
# 60        20.29  2016      3.21
# 61        13.81  2017      2.00
#
# [62 rows x 3 columns]

# %%
sns.jointplot("Rainfall", "Temperature", data= temperature, kind="reg")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot("Rainfall", "Temperature", data= temperature, kind="hex")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
